# %% [markdown]
# ## re.match()

# %%
import re

sentence1 = re.match(r'I', 'I am learning text analytics')
print(sentence1)
# Out:
# <re.Match object; span=(0, 1), match='I'>

# %%
sentence2 = re.match(r'v', 'I am learning text analytics')
print(sentence2)
# Out:
# None

# %%
sentence3 = re.match(r'am', 'I am learning text analytics')
print(sentence3)
# Out:
# None

# %% [markdown]
# ## re.search()

# %%
sentence4 = re.search(r'am', 'I am learning text analytics')
print(sentence4)
# Out:
# <re.Match object; span=(2, 4), match='am'>

# %%
sentence5 = re.search(r'am','I am learning text analytics and am enjoying it')
print(sentence5)
# Out:
# <re.Match object; span=(2, 4), match='am'>

# %% [markdown]
# ## re.findall()

# %%
sentence6 = re.findall(r'am', 'I am learning text analytics and am enjoying it')
print(sentence6)
# Out:
# ['am', 'am']

# %% [markdown]
# ## re.split()

# %%
sentence7 = re.split(r'and', 'I am learning text analytics and am enjoying it')
print(sentence7)
# Out:
# ['I am learning text analytics ', ' am enjoying it']

# %%
sentence8 = re.split(r'am', 'I am learning text analytics am enjoying it')
print (sentence8)
# Out:
# ['I ', ' learning text analytics ', ' enjoying it']

# %%
sentence9 = re.split(r'am', 'I am learning text analytics am enjoying it', maxsplit=1)
print (sentence9)
# Out:
# ['I ', ' learning text analytics am enjoying it']

# %%
sentence10 = re.split(r'am', 'I am learning text analytics am enjoying it', maxsplit=2)
print (sentence10)
# Out:
# ['I ', ' learning text analytics ', ' enjoying it']

# %%
sentence10 = re.split(r'am', 'I am learning text analytics, I am enjoying it and I am going to ace it', maxsplit=3)
print (sentence10)
# Out:
# ['I ', ' learning text analytics, I ', ' enjoying it and I ', ' going to ace it']

# %% [markdown]
# ## re.sub()

# %%
sentence11 = re.sub(r'I', 'we','I am learning text analytics, I am enjoying it and I am going to ace it')
print(sentence11)
# Out:
# we am learning text analytics, we am enjoying it and we am going to ace it

# %% [markdown]
# ## Metacharacter .

# %%
sentence1 = re.findall(r'.', 'I am learning text analytics')
print(sentence1)
# Out:
# ['I', ' ', 'a', 'm', ' ', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', ' ', 't', 'e', 'x', 't', ' ', 'a', 'n', 'a', 'l', 'y', 't', 'i', 'c', 's']

# %%
sentence2 = re.findall(r'\w', 'I am learning text analytics')
print(sentence2)
# Out:
# ['I', 'a', 'm', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g', 't', 'e', 'x', 't', 'a', 'n', 'a', 'l', 'y', 't', 'i', 'c', 's']

# %%
sentence3 = re.findall(r'\w*', 'I am learning text analytics')
print(sentence3)
# Out:
# ['I', '', 'am', '', 'learning', '', 'text', '', 'analytics', '']

# %%
sentence4 = re.findall (r'\w+', 'I am learning text analytics')
print (sentence4)

# %%
sentence5 = re.findall (r'^\w+', 'I am learning text analytics')
print (sentence5)

# %%
sentence6 = re.findall (r'\w+$', 'I am learning text analytics')
print (sentence6)

# %%
sentence7 = re.findall (r'\w\w', 'I am learning text analytics')
print (sentence7)

# %%
sentence8 = re.findall (r'\b\w\w', 'I am learning text analytics')
print (sentence8)

# %%
sentence9 = re.findall (r'@\w+', 'user@text.com.my, user@analytics.gov.my, user@textanalytics.edu.my')
print (sentence9)
# Out:
# ['@text', '@analytics', '@textanalytics']

# %%
sentence10 = re.findall (r'@\w+.\w+','user@text.com.my, user@analytics.gov.my, user@textanalytics.edu.my')
print (sentence10)
# Out:
# ['@text.com', '@analytics.gov', '@textanalytics.edu']

# %%
sentence11 = re.findall (r'@\w+.\w+.\w+', 'user@text.com.my, user@analytics.gov.my, user@textanalytics.edu.my')
print (sentence11)
# Out:
# ['@text.com.my', '@analytics.gov.my', '@textanalytics.edu.my']

# %%
sentence12 = re.findall (r'@\w+.(\w+.\w+)', 'user@text.com.my, user@analytics.gov.my, user@education.edu.my')
print (sentence12)
# Out:
# ['com.my', 'gov.my', 'edu.my']

# %%
sentence13 = re.findall (r'\d{2}-\d{2}-\d{4}', 'Ahmad BIT(IS) 15-05-2001, Johnny BCS(SE) 20-08-2000')
print (sentence13)
# Out:
# ['15-05-2001', '20-08-2000']

# %%
sentence14 = re.findall (r'\d{2}-\d{2}-(\d{4})', 'Ahmad BIT(IS) 15-05-2001, Johnny BCS(SE) 20-08-2000')
print (sentence14)
# Out:
# ['2001', '2000']

# %%
sentence15 = re.findall(
 r'(\d{2}-\d{2}-)\d{2}(\d{2})',
 'Ahmad BIT(IS) 15-05-2001, Johnny BCS(SE) 20-08-2000'
)
dates = [d + y for d, y in sentence15]
print(dates)
# Out:
# ['15-05-01', '20-08-00']

# %%
sentence16 = re.findall (r'[aeiouAEIOU]\w+', 'I have eight story books. I often read them in afternoon')
print (sentence16)
# Out:
# ['ave', 'eight', 'ory', 'ooks', 'often', 'ead', 'em', 'in', 'afternoon']

# %%
sentence17 = re.findall (r'\b[aeiouAEIOU]\w+', 'I have eight story books. I often read them in afternoon')
print(sentence17)
# Out:
# ['eight', 'often', 'in', 'afternoon']

# %%
sentence18 = re.findall (r'\b[^aeiouAEIOU\s]\w+', 'I have eight story books. I often read them in afternoon')
print(sentence18)
# Out:
# ['have', 'story', 'books', 'read', 'them']

# %%
sentence19 = re.split (r'[;,]', 'I have many story books colouring books; I often read them in the afternoon.')
print (sentence19)
# Out:
# ['I have many story books colouring books', ' I often read them in the afternoon.']

# %%
sentence20 = re.split (r'[;,\s]', 'I have many story books, colouring books; I often read them in the afternoon.') 
print (sentence20)
# Out:
# ['I', 'have', 'many', 'story', 'books', '', 'colouring', 'books', '', 'I', 'often', 'read', 'them', 'in', 'the', 'afternoon.']

# %%
sentence21 = re.sub (r'[;,]', '.', 'I have many story books, colouring books; I often read them in the afternoon.')
print (sentence21)
# Out:
# I have many story books. colouring books. I often read them in the afternoon.
